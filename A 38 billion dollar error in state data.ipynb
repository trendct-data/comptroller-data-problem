# %% [markdown]
# # How I found a 38 billion dollar data error
#
# Looking for Medicaid spending data, I stumbled upon duplicates that seemed to be doubling the State of Connecticut Comptroller's expenditure records.
#
# Props to the comptroller's office for making these expenditures readily available, and to their quick response that it was in fact an error, and that they were working to fix it.
#
# I downloaded the data Friday, July 21 and the erronious files are preserved in this repo in the [data/](data) folder.

# %%
import pandas as pd

# %%
def get_rev():
    
    df = pd.read_csv("data/revenue_budget.csv")
    
    return df

revdf = get_rev()

# %%
def get_exp():
    
    df = pd.read_csv("data/operating_budget.csv")
    
    return df

expdf = get_exp()

# %%
revdf.head()
# Out:
#   ledger_type  fiscal_year    description                   account_descr  \
# 0     Revenue         2013  Other Revenue          Federal Aid Restricted
# 1     Revenue         2012  Other Revenue  Teacher's Certificate Licenses
# 2     Revenue         2013  Other Revenue          Federal Aid Restricted
# 3     Revenue         2016  Other Revenue    Rest. Aid not Grant Transfer
# 4     Revenue         2017  Other Revenue         Federal Aid  Restricted
#
#             revenue_category  actual_amount                 program_descr  \
# 0   Non General Fund Revenue       18421.66           In-Service Training
# 1  Licenses Permits and Fees     3776471.00              Revenue Deposits
# 2   Non General Fund Revenue       90524.54     Refugee Preventive Health
# 3   Non General Fund Revenue      235000.00       Geospatial Info Sys DOT
# 4   Non General Fund Revenue      181383.97  Asbestos TSCA/OCM Prog Grant
#
#          fund_type       fund_descr
# 0  Special Revenue  Special Revenue
# 1          General          General
# 2  Special Revenue  Special Revenue
# 3  Special Revenue  Special Revenue
# 4  Special Revenue  Special Revenue

# %%
### expdf.head()

# %%
expdf[
    (expdf["program"].str.contains("Medicaid"))
#     & (expdf["program"] == "Medicaid")
    & (expdf["program"].str.contains("Medicaid"))

    & (expdf["department"] == "Department of Social Services")
#     & (expdf["fund"] == "General Fund")
     ]
# Out:
#       ledger_type  fiscal_year        fund_type  \
# 2204      Expense         2016          General
# 2235      Expense         2016  Special Revenue
# 2360      Expense         2016  Special Revenue
# 3608      Expense         2016  Special Revenue
# 4618      Expense         2017  Special Revenue
# 5381      Expense         2016  Special Revenue
# 5944      Expense         2013          General
# 5951      Expense         2013  Special Revenue
# 6863      Expense         2013          General
# 7154      Expense         2012          General
# 8365      Expense         2014          General
# 9153      Expense         2013          General
# 11605     Expense         2014          General
# 11808     Expense         2017  Special Revenue
# 12888     Expense         2015  Special Revenue
# 14218     Expense         2014          General
# 14435     Expense         2014  Special Revenue
# 15106     Expense         2012  Special Revenue
# 15428     Expense         2013  Special Revenue
# 16786     Expense         2015  Special Revenue
# 17331     Expense         2012  Special Revenue
# 17486     Expense         2015  Special Revenue
# 17499     Expense         2013          General
# 18341     Expense         2014          General
# 18692     Expense         2014          General
# 20913     Expense         2014  Special Revenue
# 21396     Expense         2013          General
# 21725     Expense         2013          General
# 22500     Expense         2015          General
# 24035     Expense         2014          General
# 24127     Expense         2015  Special Revenue
# 24782     Expense         2014  Special Revenue
# 24796     Expense         2013  Special Revenue
# 25015     Expense         2014  Special Revenue
# 25280     Expense         2014          General
# 24127        6.669905e+06   1.661285e+06
# 24782        6.793750e+05   3.631271e+04
# 24796        2.031864e+06   5.810805e+05
# 25015        2.000000e+05   0.000000e+00
# 25280        0.000000e+00   0.000000e+00
# 25790        0.000000e+00   0.000000e+00
# 26423        8.000237e+08   7.992212e+08
# 26847        5.112695e+08   5.110686e+08
# 27613        2.469984e+09   2.407143e+09
# 27614        2.469984e+09   2.407143e+09
# 27789        3.588021e+09   3.535525e+09
# 27790        3.588021e+09   3.535525e+09
# 28136        8.191496e+07   8.191494e+07
# 28138        8.191496e+07   8.191494e+07
# 28983        0.000000e+00   0.000000e+00
# 28984        0.000000e+00   0.000000e+00

# %% [markdown]
# # Ruh roh: $12 billion on Medicaid
#
# Look below - if the data were right, spending on Medicaid (crudely just defined as anything with "Medicaid" in the name) went from 6.1 billion in 2016 to 12 billion in 2017.
#
# That looked more like a duplicate than real data though. Especially because the next table shows revenue pretty much the same from 2016 to 2017.

# %%
expdf[
    (expdf["program"].str.contains("Medicaid"))
    & (expdf["department"] == "Department of Social Services")
].groupby("fiscal_year").agg({"recommended_amount":sum,"actual_amount":sum})
# Out:
#              actual_amount  recommended_amount
# fiscal_year
# 2012          4.714312e+09        4.797967e+09
# 2013          4.898532e+09        4.952604e+09
# 2014          5.445415e+09        5.542675e+09
# 2015          5.832508e+09        5.882979e+09
# 2016          5.996890e+09        6.189301e+09
# 2017          1.204951e+10        1.228077e+10

# %%
revdf[
    (revdf["program_descr"].str.contains("Medicaid"))
    #& (revdf["department"] == "Department of Social Services")
].groupby("fiscal_year").agg({"actual_amount":sum})
# Out:
#              actual_amount
# fiscal_year
# 2012          9.422486e+06
# 2013          6.535000e+05
# 2014          2.993958e+09
# 2015          3.484596e+09
# 2016          3.605798e+09
# 2017          3.618203e+09

# %% [markdown]
# # First duplicate test: Counting rows
#
# The number of rows didn't double from 2016 to 2017, but it went up a lot. From around the 5,000ish ballpark in all previous years to 6,337 rows.

# %%
import numpy as np

# %%
expdf.groupby("fiscal_year").agg({"actual_amount":np.size})
# Out:
#              actual_amount
# fiscal_year
# 2012                4701.0
# 2013                4775.0
# 2014                5025.0
# 2015                4875.0
# 2016                4774.0
# 2017                6337.0

# %%
len(expdf[expdf["fiscal_year"] == 2017])
# Out:
# 6337

# %%
len(expdf[expdf["fiscal_year"] == 2016])
# Out:
# 4774

# %% [markdown]
# # Dupe check 2: Looking for exact duplicate numbers
#
# Another quick test -- since the dollar amounts are precise, I figured that there wouldn't be a ton of rows with the exact same dollar amount. Below I counted the number of values that appear exactly twice in the data set for each year. In all years before 2016 there were 25 or fewer, but in 2017 there were 1,653.

# %%
dupe_check = expdf.groupby(["fiscal_year","actual_amount"])\
.agg({"recommended_amount":np.size}).reset_index()

dupe_check[(dupe_check["recommended_amount"] == 2)]\
.groupby("fiscal_year").agg({"recommended_amount":np.size})
# Out:
#              recommended_amount
# fiscal_year
# 2012                       19.0
# 2013                       16.0
# 2014                       21.0
# 2015                       23.0
# 2016                       12.0
# 2017                     1653.0
